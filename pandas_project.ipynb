# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('dataanime.csv')
data
# Out:
#                                                   Title   Type Episodes  \
# 0                      Fullmetal Alchemist: Brotherhood     TV       64
# 1                                        Kimi no Na wa.  Movie        1
# 2                                              Gintama°     TV       51
# 3                                         Steins;Gate 0     TV       23
# 4                                           Steins;Gate     TV       24
# ...                                                 ...    ...      ...
# 1558                                    Kuroshitsuji II     TV       12
# 1559                              Minami-ke Natsuyasumi    OVA        1
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  Movie        1
# 1561        Persona 4 the Animation: The Factor of Hope  Movie        1
# 1562                                       Re:␣Hamatora     TV       12
#
#                 Status Start airing End airing Starting season  \
# ...

# %% [markdown]
# Display the head of our Data

# %%
data.head()
# Out:
#                               Title   Type Episodes            Status  \
# 0  Fullmetal Alchemist: Brotherhood     TV       64   Finished Airing
# 1                    Kimi no Na wa.  Movie        1   Finished Airing
# 2                          Gintama°     TV       51   Finished Airing
# 3                     Steins;Gate 0     TV       23  Currently Airing
# 4                       Steins;Gate     TV       24   Finished Airing
#
#   Start airing End airing Starting season             Broadcast time  \
# 0     2009-4-5   2010-7-4          Spring     Sundays at 17:00 (JST)
# 1    2016-8-26          -               -                          -
# 2     2015-4-8  2016-3-30          Spring  Wednesdays at 18:00 (JST)
# 3    2018-4-12          -          Spring   Thursdays at 01:35 (JST)
# 4     2011-4-6  2011-9-14          Spring  Wednesdays at 02:05 (JST)
#
#                                            Producers  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# ...

# %% [markdown]
# Display the Tail of out Data

# %%
data.tail()
# Out:
#                                                   Title   Type Episodes  \
# 1558                                    Kuroshitsuji II     TV       12
# 1559                              Minami-ke Natsuyasumi    OVA        1
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  Movie        1
# 1561        Persona 4 the Animation: The Factor of Hope  Movie        1
# 1562                                       Re:␣Hamatora     TV       12
#
#                Status Start airing End airing Starting season  \
# 1558  Finished Airing     2010-7-2  2010-9-17          Summer
# 1559  Finished Airing     2013-8-6          -               -
# 1560  Finished Airing     2009-8-1          -               -
# 1561  Finished Airing     2012-6-9          -               -
# 1562  Finished Airing     2014-7-8  2014-9-23          Summer
#
#                Broadcast time  \
# 1558                        -
# 1559                        -
# 1560                        -
# ...

# %% [markdown]
# Display the top 5 Row of out Data

# %%
data.head(5)
# Out:
#                               Title   Type Episodes            Status  \
# 0  Fullmetal Alchemist: Brotherhood     TV       64   Finished Airing
# 1                    Kimi no Na wa.  Movie        1   Finished Airing
# 2                          Gintama°     TV       51   Finished Airing
# 3                     Steins;Gate 0     TV       23  Currently Airing
# 4                       Steins;Gate     TV       24   Finished Airing
#
#   Start airing End airing Starting season             Broadcast time  \
# 0     2009-4-5   2010-7-4          Spring     Sundays at 17:00 (JST)
# 1    2016-8-26          -               -                          -
# 2     2015-4-8  2016-3-30          Spring  Wednesdays at 18:00 (JST)
# 3    2018-4-12          -          Spring   Thursdays at 01:35 (JST)
# 4     2011-4-6  2011-9-14          Spring  Wednesdays at 02:05 (JST)
#
#                                            Producers  \
# 0  Aniplex,Square Enix,Mainichi Broadcasting Syst...
# ...

# %% [markdown]
# Display the bottom 5 row of out Data

# %%
data.tail(5)
# Out:
#                                                   Title   Type Episodes  \
# 1558                                    Kuroshitsuji II     TV       12
# 1559                              Minami-ke Natsuyasumi    OVA        1
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  Movie        1
# 1561        Persona 4 the Animation: The Factor of Hope  Movie        1
# 1562                                       Re:␣Hamatora     TV       12
#
#                Status Start airing End airing Starting season  \
# 1558  Finished Airing     2010-7-2  2010-9-17          Summer
# 1559  Finished Airing     2013-8-6          -               -
# 1560  Finished Airing     2009-8-1          -               -
# 1561  Finished Airing     2012-6-9          -               -
# 1562  Finished Airing     2014-7-8  2014-9-23          Summer
#
#                Broadcast time  \
# 1558                        -
# 1559                        -
# 1560                        -
# ...

# %% [markdown]
# Get the row of out data by its index number

# %%
data.loc[1]
# Out:
# Title                                                 Kimi no Na wa.
# Type                                                           Movie
# Episodes                                                           1
# Status                                               Finished Airing
# Start airing                                               2016-8-26
# End airing                                                         -
# Starting season                                                    -
# Broadcast time                                                     -
# Producers          Kadokawa Shoten,Toho,Sound Team Don Juan,Lawso...
# Licensors                                       Funimation,NYAV Post
# Studios                                             CoMix Wave Films
# Sources                                                     Original
# Genres                             Supernatural,Drama,Romance,School
# Duration                                               1 hr. 46 min.
# ...

# %%
data.loc[2]
# Out:
# Title                                                       Gintama°
# Type                                                              TV
# Episodes                                                          51
# Status                                               Finished Airing
# Start airing                                                2015-4-8
# End airing                                                 2016-3-30
# Starting season                                               Spring
# Broadcast time                             Wednesdays at 18:00 (JST)
# Producers                                    TV Tokyo,Aniplex,Dentsu
# Licensors                                     Funimation,Crunchyroll
# Studios                                        Bandai Namco Pictures
# Sources                                                        Manga
# Genres             Action,Comedy,Historical,Parody,Samurai,Sci-Fi...
# Duration                                             24 min. per ep.
# ...

# %%
data.loc[6]
# Out:
# Title                                                       Gintama'
# Type                                                              TV
# Episodes                                                          51
# Status                                               Finished Airing
# Start airing                                                2011-4-4
# End airing                                                 2012-3-26
# Starting season                                               Spring
# Broadcast time                                Mondays at 18:00 (JST)
# Producers          TV Tokyo,Aniplex,Dentsu,Trinity Sound,Miracle ...
# Licensors                                                          -
# Studios                                                      Sunrise
# Sources                                                        Manga
# Genres             Action,Sci-Fi,Comedy,Historical,Parody,Samurai...
# Duration                                             24 min. per ep.
# ...

# %% [markdown]
# Get a specific Column

# %%
data.loc[1,'Type']
# Out:
# 'Movie'

# %% [markdown]
# Another way

# %%
data.loc[6]['Members']
# Out:
# np.int64(212238)

# %%
data.shape
# Out:
# (1563, 20)

# %%
data.size
# Out:
# 31260

# %%
data.Type
# Out:
# 0          TV
# 1       Movie
# 2          TV
# 3          TV
# 4          TV
#         ...
# 1558       TV
# 1559      OVA
# 1560    Movie
# 1561    Movie
# 1562       TV
# Name: Type, Length: 1563, dtype: str

# %%
data.dtypes
# Out:
# Title                  str
# Type                   str
# Episodes               str
# Status                 str
# Start airing           str
# End airing             str
# Starting season        str
# Broadcast time         str
# Producers              str
# Licensors              str
# Studios                str
# Sources                str
# Genres                 str
# Duration               str
# Rating                 str
# Score              float64
# Scored by            int64
# Members              int64
# Favorites            int64
# Description            str
# dtype: object

# %%
data['Episodes'].head()
# Out:
# 0    64
# 1     1
# 2    51
# 3    23
# 4    24
# Name: Episodes, dtype: str

# %%
data['Episodes'] = pd.to_numeric(data['Episodes'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Episodes    '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...
